# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"] ,index=["x","y","z"])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df["A"].mean()
# Out:
# np.float64(4.0)

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['A', 'B', 'C']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df["A"].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# # Loading in dataframes from files

# %%
coffee = pd.read_csv("./coffeedata/coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./data/results.parquet')
bios = pd.read_csv('./data/bios.csv')

# %%
## To read an excel spreadsheet
olympics_data = pd.read_excel('./data/olympics-data.xlsx', sheet_name="results")

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 5   Wednesday       Latte          25
# 4   Wednesday    Espresso          35
# 12     Sunday    Espresso          45

# %%
# loc
# coffee.loc[Rows, Columns]
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[1:5,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.index = coffee["Day"]

# %%
coffee.loc["Monday":"Wednesday", "Units Sold"]
# Out:
# Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
coffee = pd.read_csv('./coffeedata/coffee.csv')

# %%
coffee.loc[1:3, "Units Sold"] = 10

# %%
coffee.at[0,"Units Sold"]
# Out:
# np.int64(25)

# %%
coffee.iat[3,1]
# Out:
# 'Latte'

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values(["Units Sold"],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(["Units Sold","Coffee Type"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
# for iterating over dataframe 
for i,row in coffee.iterrows():
    print(i)
    print(row)
    print("Coffer Type: ",row["Coffee Type"])
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Coffer Type:  Espresso
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# Coffer Type:  Latte
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# Coffer Type:  Espresso
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# Coffer Type:  Latte
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# Coffer Type:  Espresso
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Coffer Type:  Latte
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Coffer Type:  Espresso
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
# Coffer Type:  Latte
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
# Coffer Type:  Espresso
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
# Coffer Type:  Latte
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
# Coffer Type:  Espresso
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
# Coffer Type:  Latte
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
# Coffer Type:  Espresso
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object
# Coffer Type:  Latte

# %% [markdown]
# filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios["height_cm"]> 215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# 6722          6755       Shaquille O'Neal  1972-03-06                  Newark
# 6937          6972         David Robinson  1965-08-06                Key West
# 6978          7013        Arvydas Sabonis  1964-12-19                  Kaunas
# 7074          7111         Paulo da Silva  1963-07-21               São Paulo
# 7188          7226     Vladimir Tkachenko  1957-09-20               Golovinka
# 7281          7320       Stojko Vranković  1964-01-22                   Drniš
# 7376          7416    Eurelijus Žukauskas  1973-08-22                Klaipėda
# 52608        52983        Aleksey Kazakov  1976-03-18      Naberezhnye Chelny
# 82100        82753          Frédéric Weis  1977-06-22              Thionville
# 89070        89782               Yao Ming  1980-09-12          Xuhui District
# 89075        89787         Roberto Dueñas  1975-11-01                  Madrid
# 107408      108533       Peter John Ramos  1985-05-23                 Fajardo
# 112312      113568           Stanko Barać  1986-08-13                  Mostar
# 112332      113588    Andreas Glyniadakis  1981-08-26                  Chania
# 112337      113593          Hamed Haddadi  1985-05-19                   Ahvaz
# 118663      120400         Timofey Mozgov  1986-07-16                     NaN
# 118676      120415        Dmitry Musersky  1988-10-29                Makiïvka
# 120266      122147           Zhang Zhaoxu  1987-11-18                 Binzhou
# 121694      123709            Salah Mejri  1986-06-15                Jendouba
# 123850      126093         Tyson Chandler  1982-10-02                 Hanford
# 130460      133147               Li Muhao  1992-06-02                 Guiyang
# 130461      133148                Zhou Qi  1996-01-16                Xinxiang
# 138671      142084          Ondřej Balvín  1992-09-20          Ústí nad Labem
# 139365      142836         Moustapha Fall  1992-02-23                   Paris
#
#                             born_region born_country  \
# 5089                             Moskva          RUS
# 5583                          São Paulo          BRA
# 5673                Nordrhein-Westfalen          GER
# 5716                             Bayern          GER
# 5781                     North Carolina          USA
# 5796                           Victoria          AUS
# 6223                        Hovedstaden          DEN
# 6270                                NaN          NaN
# 6409                                NaN          NaN
# 6420                        Cēsu novads          LAT
# 6504                           Victoria          AUS
# 6722                         New Jersey          USA
# 6937                            Florida          USA
# 6978                             Kaunas          LTU
# 7074                          São Paulo          BRA
# 7188                     Krasnodar Kray          RUS
# 7281          Šibensko-kninska županija          CRO
# 7376                           Klaipėda          LTU
# 52608              Respublika Tatarstan          RUS
# 82100                           Moselle          FRA
# 89070                          Shanghai          CHN
# 89075                            Madrid          ESP
# 107408                      Puerto Rico          PUR
# 112312  Hercegovačko-neretvanski kanton          BIH
# 112332                            Kriti          GRE
# 112337                        Khuzestan          IRI
# 118663                              NaN          NaN
# 118676                          Donetsk          UKR
# 120266                         Shandong          CHN
# 121694                         Jendouba          TUN
# 123850                       California          USA
# 130460                          Guizhou          CHN
# 130461                            Henan          CHN
# 138671                     Ústecký kraj          CZE
# 139365                            Paris          FRA
#
#                                NOC  height_cm  weight_kg   died_date
# 5089                  Soviet Union      220.0      112.0  1993-07-24
# 5583                        Brazil      217.0      106.0         NaN
# 5673                       Germany      221.0      114.0         NaN
# 5716          Germany West Germany      218.0      110.0         NaN
# 5781                 United States      223.0      102.0         NaN
# 5796                     Australia      218.0       93.0         NaN
# 6223                        Canada      216.0      105.0         NaN
# 6270    People's Republic of China      216.0      135.0         NaN
# 6409                  Soviet Union      216.0      111.0  2004-11-18
# 6420                  Soviet Union      218.0      141.0  1994-11-20
# 6504                     Australia      220.0      135.0         NaN
# 6722                 United States      216.0      137.0         NaN
# 6937                 United States      216.0      107.0         NaN
# 6978        Lithuania Soviet Union      223.0      122.0         NaN
# 7074                        Brazil      217.0      106.0         NaN
# 7188                  Soviet Union      220.0      110.0         NaN
# 7281            Croatia Yugoslavia      217.0      115.0         NaN
# 7376                     Lithuania      218.0      115.0         NaN
# 52608           Russian Federation      217.0      102.0         NaN
# 82100                       France      218.0      110.0         NaN
# 89070   People's Republic of China      226.0      141.0         NaN
# 89075                        Spain      221.0      137.0         NaN
# 107408                 Puerto Rico      219.0      113.0         NaN
# 112312                     Croatia      217.0      110.0         NaN
# 112332                      Greece      216.0      115.0         NaN
# 112337    Islamic Republic of Iran      218.0      110.0         NaN
# 118663          Russian Federation      216.0      113.0         NaN
# 118676          Russian Federation      219.0      104.0         NaN
# 120266  People's Republic of China      221.0      110.0         NaN
# 121694                     Tunisia      216.0      110.0         NaN
# 123850               United States      216.0      107.0         NaN
# 130460  People's Republic of China      218.0      115.0         NaN
# 130461  People's Republic of China      217.0       95.0         NaN
# 138671                     Czechia      216.0      107.0         NaN
# 139365                      France      218.0        NaN         NaN

# %%
bios.loc[bios["weight_kg"]>100]
# Out:
#         athlete_id                  name   born_date      born_city  \
# 300            301          Jackson Fear  1978-01-13         Sydney
# 524            526  Bernhard Schulkowski  1951-10-09       Hanstedt
# 1080          1087        Bozhil Lozanov  1934-08-16            NaN
# 1482          1489        José Contreras  1971-12-06   Las Martinas
# 1493          1500       Pedro Luis Lazo  1973-04-15  Pinar del Río
# ...            ...                   ...         ...            ...
# 144548      148240    Mathias Bau Hansen  1993-07-03       Glostrup
# 144558      148250      Oliver Lauridsen  1989-03-24       Gentofte
# 145259      148979      Juraj Slafkovský  2004-03-30         Košice
# 145263      148983         Marián Skupek  2001-07-12        Gelnica
# 145459      149186       Roberts Mamčics  1995-04-06        Liepāja
#
#             born_region born_country           NOC  height_cm  weight_kg  \
# 300     New South Wales          AUS     Australia      178.0      125.0
# 524       Niedersachsen          GER  West Germany      195.0      105.0
# 1080                NaN          NaN      Bulgaria      208.0      133.0
# 1482      Pinar del Río          CUB          Cuba      191.0      107.0
# 1493      Pinar del Río          CUB          Cuba      192.0      107.0
# ...                 ...          ...           ...        ...        ...
# 144548      Hovedstaden          DEN       Denmark      200.0      108.0
# 144558      Hovedstaden          DEN       Denmark      198.0      108.0
# 145259           Košice          SVK      Slovakia      192.0      102.0
# 145263           Košice          SVK      Slovakia      196.0      108.0
# 145459          Liepāja          LAT        Latvia      196.0      105.0
#
#          died_date
# 300     2006-07-21
# 524            NaN
# 1080           NaN
# 1482           NaN
# 1493           NaN
# ...            ...
# 144548         NaN
# 144558         NaN
# 145259         NaN
# 145263         NaN
# 145459         NaN
#
# [3105 rows x 10 columns]

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios["height_cm"] > 215, ["name", "height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
bios.loc[bios["weight_kg"]>100][["name","weight_kg"]]
# Out:
#                         name  weight_kg
# 300             Jackson Fear      125.0
# 524     Bernhard Schulkowski      105.0
# 1080          Bozhil Lozanov      133.0
# 1482          José Contreras      107.0
# 1493         Pedro Luis Lazo      107.0
# ...                      ...        ...
# 144548    Mathias Bau Hansen      108.0
# 144558      Oliver Lauridsen      108.0
# 145259      Juraj Slafkovský      102.0
# 145263         Marián Skupek      108.0
# 145459       Roberts Mamčics      105.0
#
# [3105 rows x 2 columns]

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios["name"].str.contains("keith",case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 1897                  NaN          NaN        Ireland        NaN        NaN
# 3505              England          GBR  Great Britain      165.0       51.0
# 6228     British Columbia          CAN         Canada      200.0       85.0
# 8898                  NaN          NaN         Zambia        NaN        NaN
# 12053             England          GBR  Great Britain        NaN        NaN
# ...                   ...          ...            ...        ...        ...
# 109900         Canterbury          NZL    New Zealand        NaN        NaN
# 115973      Massachusetts          USA  United States      183.0       95.0
# 117676           Manitoba          CAN         Canada      185.0       88.0
# 122121           Victoria          AUS      Australia      176.0       78.0
# 127310  Manawatu-Wanganui          NZL   Cook Islands      167.0       60.0
#
#          died_date
# 1897           NaN
# 3505    1999-12-31
# 6228           NaN
# 8898    1993-01-09
# 12053   1973-02-22
# ...            ...
# 109900  2013-11-15
# 115973         NaN
# 117676         NaN
# 122121         NaN
# 127310         NaN
#
# [70 rows x 10 columns]

# %%
# Regex syntax
bios[bios['name'].str.contains('keith|patrick', case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 6               Essonne          FRA         France      180.0       73.0
# 119       KwaZulu-Natal          RSA  Great Britain        NaN        NaN
# 319     Oost-Vlaanderen          BEL        Belgium      178.0       92.0
# 1897                NaN          NaN        Ireland        NaN        NaN
# 2115                NaN          NaN    Switzerland      176.0       67.0
# ...                 ...          ...            ...        ...        ...
# 143975              NaN          NaN         Zambia        NaN        NaN
# 144172            Tirol          AUT        Austria        NaN        NaN
# 144547       Syddanmark          DEN        Denmark        NaN        NaN
# 144565      Hovedstaden          DEN        Denmark      186.0       93.0
# 145435         Illinois          USA  United States        NaN        NaN
#
#          died_date
# 6              NaN
# 119     1967-11-05
# 319            NaN
# 1897           NaN
# 2115           NaN
# ...            ...
# 143975         NaN
# 144172         NaN
# 144547         NaN
# 144565         NaN
# 145435  2023-06-12
#
# [303 rows x 10 columns]

# %%
# Other cool regex filters

# Find athletes born in cities that start with a vowel:
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]

# Find athletes with names that contain exactly two vowels:
two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

# Find athletes with names that have repeated consecutive letters (e.g., "Aaron", "Emmett"):
repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]

# Find athletes with names ending in 'son' or 'sen':
son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]

# Find athletes born in a year starting with '19':
born_19xx = bios[bios['born_date'].str.contains(r'^19', na=False)]

# Find athletes with names that do not contain any vowels:
no_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*$', na=False)]

# Find athletes whose names contain a hyphen or an apostrophe:
hyphen_apostrophe = bios[bios['name'].str.contains(r"[-']", na=False)]

# Find athletes with names that start and end with the same letter:
start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]

# Find athletes with a born_city that has exactly 7 characters:
city_seven_chars = bios[bios['born_city'].str.contains(r'^.{7}$', na=False)]

# Find athletes with names containing three or more vowels:
three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15480\1859696338.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15480\1859696338.py:25: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15480\1859696338.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]

# %%
# Don't use regex search (exact match)
bios[bios['name'].str.contains('keith|patrick', case=False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
## isin method & startswith
bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# 57818        58226        Keith Peache  1947-08-10              Lewisham
# 61748        62202       Keith Grogono  1912-11-04             Stratford
# 62620        63086         Keith Musto  1936-01-12              Rochford
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 68324        68841         Keith Angus  1943-04-05             Sheffield
# 68472        68989        Keith Cullen  1972-06-13                Ilford
# 68997        69514         Keith Stock  1957-03-18              Woolwich
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 95267        96037        Keith Oliver  1947-10-27             Liverpool
# 96452        97229  Keith Schellenberg  1929-03-13         Middlesbrough
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 3505          England          GBR  Great Britain      165.0       51.0
# 12053         England          GBR  Great Britain        NaN        NaN
# 14577         England          GBR  Great Britain        NaN        NaN
# 16166         England          GBR  Great Britain      173.0       68.0
# 18734         England          GBR  Great Britain      190.0       79.0
# 29897         England          GBR  Great Britain      173.0       70.0
# 34011         England          GBR  Great Britain      193.0      114.0
# 46885         England          GBR  Great Britain      168.0       63.0
# 50929            Ohio          USA  United States        NaN        NaN
# 51185         Arizona          USA  United States      188.0       73.0
# 52913      California          USA  United States      196.0       86.0
# 55317         England          GBR  Great Britain      170.0       87.0
# 57818         England          GBR  Great Britain      180.0       98.0
# 61748         England          GBR  Great Britain        NaN        NaN
# 62620         England          GBR  Great Britain      174.0       72.0
# 62678         Florida          USA  United States      170.0       66.0
# 68324         England          GBR  Great Britain      170.0       59.0
# 68472         England          GBR  Great Britain      177.0       61.0
# 68997         England          GBR  Great Britain      176.0       73.0
# 77550        Illinois          USA  United States      180.0       64.0
# 84097       Minnesota          USA  United States      165.0       69.0
# 94646        Illinois          USA  United States        NaN        NaN
# 95267         England          GBR  Great Britain      172.0       68.0
# 96452         England          GBR  Great Britain        NaN        NaN
# 97499   Massachusetts          USA  United States      188.0      102.0
# 98068        Colorado          USA  United States        NaN        NaN
# 99921    Rhode Island          USA  United States      188.0       93.0
# 115973  Massachusetts          USA  United States      183.0       95.0
#
#          died_date
# 3505    1999-12-31
# 12053   1973-02-22
# 14577          NaN
# 16166          NaN
# 18734          NaN
# 29897          NaN
# 34011   2015-09-16
# 46885   1991-03-06
# 50929   2013-05-03
# 51185          NaN
# 52913          NaN
# 55317          NaN
# 57818          NaN
# 61748   1999-03-22
# 62620          NaN
# 62678          NaN
# 68324          NaN
# 68472          NaN
# 68997          NaN
# 77550          NaN
# 84097   2018-11-05
# 94646   2010-07-25
# 95267          NaN
# 96452   2019-10-28
# 97499          NaN
# 98068   1974-08-22
# 99921          NaN
# 115973         NaN

# %% [markdown]
# Query functions ``

# %%
bios.query("born_country == 'USA' and born_city=='Seattle'")
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 11030           USA  United States      178.0       79.0         NaN
# 12800           USA  United States      180.0       75.0         NaN
# 15476           USA  United States      183.0       75.0         NaN
# 29079           USA  United States      156.0       49.0         NaN
# 31135           USA  United States        NaN        NaN  2001-07-08
# ...             ...            ...        ...        ...         ...
# 133392          USA  United States      188.0       91.0         NaN
# 135448          USA       Colombia        NaN        NaN         NaN
# 136993          USA  United States        NaN        NaN         NaN
# 143507          USA  United States      175.0       73.0         NaN
# 145446          USA  United States        NaN        NaN         NaN
#
# [102 rows x 10 columns]

# %% [markdown]
# adding and removing

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee["Price"] = 4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          10   4.99
# 2     Tuesday    Espresso          10   4.99
# 3     Tuesday       Latte          10   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
coffee["new Price"] = np.where(coffee["Coffee Type"]=="Espresso",3.99,5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  new Price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          10   4.99       3.99
# 3     Tuesday       Latte          10   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee["new Price"] = np.where(coffee["Coffee Type"]== "Latte",2.22,5.95)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  new Price
# 0      Monday    Espresso          25   4.99       5.95
# 1      Monday       Latte          10   4.99       2.22
# 2     Tuesday    Espresso          10   4.99       5.95
# 3     Tuesday       Latte          10   4.99       2.22
# 4   Wednesday    Espresso          35   4.99       5.95
# 5   Wednesday       Latte          25   4.99       2.22
# 6    Thursday    Espresso          40   4.99       5.95
# 7    Thursday       Latte          30   4.99       2.22
# 8      Friday    Espresso          45   4.99       5.95
# 9      Friday       Latte          35   4.99       2.22
# 10   Saturday    Espresso          45   4.99       5.95
# 11   Saturday       Latte          35   4.99       2.22
# 12     Sunday    Espresso          45   4.99       5.95
# 13     Sunday       Latte          35   4.99       2.22

# %%
coffee.drop(columns=['Price'],inplace =True)

# %%
coffee["revenue"] = coffee["Units Sold"] * coffee["new Price"]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new Price  revenue
# 0      Monday    Espresso          25       5.95   148.75
# 1      Monday       Latte          10       2.22    22.20
# 2     Tuesday    Espresso          10       5.95    59.50
# 3     Tuesday       Latte          10       2.22    22.20
# 4   Wednesday    Espresso          35       5.95   208.25
# 5   Wednesday       Latte          25       2.22    55.50
# 6    Thursday    Espresso          40       5.95   238.00
# 7    Thursday       Latte          30       2.22    66.60
# 8      Friday    Espresso          45       5.95   267.75
# 9      Friday       Latte          35       2.22    77.70
# 10   Saturday    Espresso          45       5.95   267.75
# 11   Saturday       Latte          35       2.22    77.70
# 12     Sunday    Espresso          45       5.95   267.75
# 13     Sunday       Latte          35       2.22    77.70

# %%
coffee.rename(columns={'new Price':'price'},inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   5.95   148.75
# 1      Monday       Latte          10   2.22    22.20
# 2     Tuesday    Espresso          10   5.95    59.50
# 3     Tuesday       Latte          10   2.22    22.20
# 4   Wednesday    Espresso          35   5.95   208.25
# 5   Wednesday       Latte          25   2.22    55.50
# 6    Thursday    Espresso          40   5.95   238.00
# 7    Thursday       Latte          30   2.22    66.60
# 8      Friday    Espresso          45   5.95   267.75
# 9      Friday       Latte          35   2.22    77.70
# 10   Saturday    Espresso          45   5.95   267.75
# 11   Saturday       Latte          35   2.22    77.70
# 12     Sunday    Espresso          45   5.95   267.75
# 13     Sunday       Latte          35   2.22    77.70

# %%
bios_new = bios.copy()

# %%
bios_new["first_name"] = bios_new["name"].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name
# 0       1960-10-02  Jean-François
# 1              NaN         Arnaud
# 2       1994-07-17           Jean
# 3       1978-03-20        Jacques
# 4       1930-07-25         Albert
# ...            ...            ...
# 145495         NaN         Polina
# 145496         NaN       Valeriya
# 145497         NaN         Yuliya
# 145498  1986-03-18          André
# 145499  2003-10-20           Bill
#
# [145500 rows x 11 columns]

# %%
bios_new["last"] = bios_new["name"].str.split(' ').str[1]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name        last
# 0       1960-10-02  Jean-François     Blanchy
# 1              NaN         Arnaud     Boetsch
# 2       1994-07-17           Jean     Borotra
# 3       1978-03-20        Jacques     Brugnon
# 4       1930-07-25         Albert       Canet
# ...            ...            ...         ...
# 145495         NaN         Polina  Luchnikova
# 145496         NaN       Valeriya  Merkusheva
# 145497         NaN         Yuliya    Smirnova
# 145498  1986-03-18          André    Foussard
# 145499  2003-10-20           Bill    Phillips
#
# [145500 rows x 12 columns]

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# 3505             England          GBR  Great Britain      165.0       51.0
# 6228    British Columbia          CAN         Canada      200.0       85.0
# 8898                 NaN          NaN         Zambia        NaN        NaN
# 12053            England          GBR  Great Britain        NaN        NaN
# ...                  ...          ...            ...        ...        ...
# 99921       Rhode Island          USA  United States      188.0       93.0
# 102227           Ontario          CAN         Canada      185.0       75.0
# 109900        Canterbury          NZL    New Zealand        NaN        NaN
# 115973     Massachusetts          USA  United States      183.0       95.0
# 122121          Victoria          AUS      Australia      176.0       78.0
#
#          died_date first_name         last
# 1897           NaN      Keith       Hanlon
# 3505    1999-12-31      Keith      Wallace
# 6228           NaN      Keith      Hartley
# 8898    1993-01-09      Keith        Mwila
# 12053   1973-02-22      Keith       Hervey
# ...            ...        ...          ...
# 99921          NaN      Keith       Carney
# 102227         NaN      Keith      Beavers
# 109900  2013-11-15      Keith  Cumberpatch
# 115973         NaN      Keith    Sanderson
# 122121         NaN      Keith     Ferguson
#
# [64 rows x 12 columns]

# %%
bios_new["born_datetime"] = pd.to_datetime(bios_new["born_date"])

# %%
bios_new["born_year"] = bios_new["born_datetime"].dt.year

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name        last born_datetime  born_year
# 0       1960-10-02  Jean-François     Blanchy    1886-12-12     1886.0
# 1              NaN         Arnaud     Boetsch    1969-04-01     1969.0
# 2       1994-07-17           Jean     Borotra    1898-08-13     1898.0
# 3       1978-03-20        Jacques     Brugnon    1895-05-11     1895.0
# 4       1930-07-25         Albert       Canet    1878-04-17     1878.0
# ...            ...            ...         ...           ...        ...
# 145495         NaN         Polina  Luchnikova    2002-01-30     2002.0
# 145496         NaN       Valeriya  Merkusheva    1999-09-20     1999.0
# 145497         NaN         Yuliya    Smirnova    1998-05-08     1998.0
# 145498  1986-03-18          André    Foussard    1899-05-19     1899.0
# 145499  2003-10-20           Bill    Phillips    1913-07-15     1913.0
#
# [145500 rows x 14 columns]

# %%
bios_new[["name","born_year"]]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv("./data/bios_new.csv",index=False)

# %%
bios["height_category"] = bios["height_cm"].apply(lambda x: "short" if x <165 else("Average" if x < 185 else 'Tall'))

# %%
def categorize_althlete(row):
    if row["height_cm"] < 175 and row["weight_kg"] < 70:
        return "lightWeight"
    elif row["height_cm"] or row["weight_kg"] <= 80:
        return "Middleweight"
    else:
        return "heavy weight"

bios["category"] = bios.apply(categorize_althlete,axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02            Tall  Middleweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   lightWeight
# 4  1930-07-25            Tall  Middleweight

# %% [markdown]
# merging & concating data

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02            Tall  Middleweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   lightWeight
# 4  1930-07-25            Tall  Middleweight

# %%
bios_new = pd.merge(bios,nocs,left_on="born_country",right_on="NOC",how="left")

# %%
bios_new.rename(columns={'region':'born_country_full'},inplace=True)

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category      category NOC_y born_country_full notes
# 0       1960-10-02            Tall  Middleweight   FRA            France   NaN
# 1              NaN         Average  Middleweight   FRA            France   NaN
# 2       1994-07-17         Average  Middleweight   FRA            France   NaN
# 3       1978-03-20         Average   lightWeight   FRA            France   NaN
# 4       1930-07-25            Tall  Middleweight   GBR                UK   NaN
# ...            ...             ...           ...   ...               ...   ...
# 145495         NaN         Average   lightWeight   RUS            Russia   NaN
# 145496         NaN         Average   lightWeight   RUS            Russia   NaN
# 145497         NaN           short   lightWeight   RUS            Russia   NaN
# 145498  1986-03-18         Average  Middleweight   FRA            France   NaN
# 145499  2003-10-20            Tall  Middleweight   AUS         Australia   NaN
#
# [145500 rows x 15 columns]

# %%
bios_new[bios_new["NOC_x"]!=bios_new["born_country_full"]][["name","NOC_x","NOC_y"]]
# Out:
#                        name    NOC_x NOC_y
# 4              Albert Canet   France   GBR
# 12                J. Defert   France   NaN
# 13           Étienne Durand   France   NaN
# 16               Guy Forget   France   MAR
# 27       Guy, Baron Lejeune   France   NaN
# ...                     ...      ...   ...
# 145491        Matthew Wepke  Jamaica   NaN
# 145493   Landysh Falyakhova      ROC   RUS
# 145495    Polina Luchnikova      ROC   RUS
# 145496  Valeriya Merkusheva      ROC   RUS
# 145497      Yuliya Smirnova      ROC   RUS
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country']=="USA"].copy()
gbr = bios[bios['born_country']=="GBR"].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category      category
# 54           Average  Middleweight
# 960          Average   lightWeight
# 961            short   lightWeight
# 1231            Tall  Middleweight
# 1345         Average   lightWeight

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN
#
#    height_category      category
# 4             Tall  Middleweight
# 37            Tall  Middleweight
# 38            Tall  Middleweight
# 39            Tall  Middleweight
# 40         Average  Middleweight

# %%
ew_df = pd.concat([usa,gbr])

# %%
ew_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category      category
# 144811            Tall  Middleweight
# 144815            Tall  Middleweight
# 145005         Average  Middleweight
# 145319            Tall  Middleweight
# 145388            Tall  Middleweight

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(results,bios,on="athlete_id",how="left")

# %%
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied  ...   born_date   born_city born_region born_country       NOC  \
# 0        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 1       False  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 2        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 3        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 4       False  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# ...       ...  ...         ...         ...         ...          ...       ...
# 308403  False  ...  2001-07-12     Gelnica      Košice          SVK  Slovakia
# 308404  False  ...  1998-03-28    Vemdalen    Jämtland          SWE    Sweden
# 308405  False  ...  2000-08-16        Täby   Stockholm          SWE    Sweden
# 308406  False  ...  2000-08-16        Täby   Stockholm          SWE    Sweden
# 308407  False  ...  1994-10-07  Kungsbacka     Halland          SWE    Sweden
#
#        height_cm weight_kg   died_date  height_category      category
# 0            NaN       NaN  1960-10-02             Tall  Middleweight
# 1            NaN       NaN  1960-10-02             Tall  Middleweight
# 2            NaN       NaN  1960-10-02             Tall  Middleweight
# 3            NaN       NaN  1960-10-02             Tall  Middleweight
# 4            NaN       NaN  1960-10-02             Tall  Middleweight
# ...          ...       ...         ...              ...           ...
# 308403     196.0     108.0         NaN             Tall  Middleweight
# 308404       NaN       NaN         NaN             Tall  Middleweight
# 308405       NaN       NaN         NaN             Tall  Middleweight
# 308406       NaN       NaN         NaN             Tall  Middleweight
# 308407       NaN       NaN         NaN             Tall  Middleweight
#
# [308408 rows x 22 columns]

# %% [markdown]
# handling the null value

# %%
coffee.loc[[0,1],"Units Sold"] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   5.95   148.75
# 1      Monday       Latte         NaN   2.22    22.20
# 2     Tuesday    Espresso        10.0   5.95    59.50
# 3     Tuesday       Latte        10.0   2.22    22.20
# 4   Wednesday    Espresso        35.0   5.95   208.25
# 5   Wednesday       Latte        25.0   2.22    55.50
# 6    Thursday    Espresso        40.0   5.95   238.00
# 7    Thursday       Latte        30.0   2.22    66.60
# 8      Friday    Espresso        45.0   5.95   267.75
# 9      Friday       Latte        35.0   2.22    77.70
# 10   Saturday    Espresso        45.0   5.95   267.75
# 11   Saturday       Latte        35.0   2.22    77.70
# 12     Sunday    Espresso        45.0   5.95   267.75
# 13     Sunday       Latte        35.0   2.22    77.70

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee.loc[[4,6],"Units Sold"] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   5.95   148.75
# 1      Monday       Latte         NaN   2.22    22.20
# 2     Tuesday    Espresso        10.0   5.95    59.50
# 3     Tuesday       Latte        10.0   2.22    22.20
# 4   Wednesday    Espresso         NaN   5.95   208.25
# 5   Wednesday       Latte        25.0   2.22    55.50
# 6    Thursday    Espresso         NaN   5.95   238.00
# 7    Thursday       Latte        30.0   2.22    66.60
# 8      Friday    Espresso        45.0   5.95   267.75
# 9      Friday       Latte        35.0   2.22    77.70
# 10   Saturday    Espresso        45.0   5.95   267.75
# 11   Saturday       Latte        35.0   2.22    77.70
# 12     Sunday    Espresso        45.0   5.95   267.75
# 13     Sunday       Latte        35.0   2.22    77.70

# %%
coffee["Units Sold"].interpolate()
# Out:
# 0      NaN
# 1      NaN
# 2     10.0
# 3     10.0
# 4     17.5
# 5     25.0
# 6     27.5
# 7     30.0
# 8     45.0
# 9     35.0
# 10    45.0
# 11    35.0
# 12    45.0
# 13    35.0
# Name: Units Sold, dtype: float64

# %%
coffee["Units Sold"] = coffee["Units Sold"].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   5.95   148.75
# 1      Monday       Latte         NaN   2.22    22.20
# 2     Tuesday    Espresso        10.0   5.95    59.50
# 3     Tuesday       Latte        10.0   2.22    22.20
# 4   Wednesday    Espresso        17.5   5.95   208.25
# 5   Wednesday       Latte        25.0   2.22    55.50
# 6    Thursday    Espresso        27.5   5.95   238.00
# 7    Thursday       Latte        30.0   2.22    66.60
# 8      Friday    Espresso        45.0   5.95   267.75
# 9      Friday       Latte        35.0   2.22    77.70
# 10   Saturday    Espresso        45.0   5.95   267.75
# 11   Saturday       Latte        35.0   2.22    77.70
# 12     Sunday    Espresso        45.0   5.95   267.75
# 13     Sunday       Latte        35.0   2.22    77.70

# %%
coffee["Units Sold"] = coffee["Units Sold"].fillna(coffee["Units Sold"].mean())

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        30.0   5.95   148.75
# 1      Monday       Latte        30.0   2.22    22.20
# 2     Tuesday    Espresso        10.0   5.95    59.50
# 3     Tuesday       Latte        10.0   2.22    22.20
# 4   Wednesday    Espresso        17.5   5.95   208.25
# 5   Wednesday       Latte        25.0   2.22    55.50
# 6    Thursday    Espresso        27.5   5.95   238.00
# 7    Thursday       Latte        30.0   2.22    66.60
# 8      Friday    Espresso        45.0   5.95   267.75
# 9      Friday       Latte        35.0   2.22    77.70
# 10   Saturday    Espresso        45.0   5.95   267.75
# 11   Saturday       Latte        35.0   2.22    77.70
# 12     Sunday    Espresso        45.0   5.95   267.75
# 13     Sunday       Latte        35.0   2.22    77.70

# %%
coffee = coffee.dropna(subset=["Units Sold"],inplace=True)
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        30.0   5.95   148.75
# 1      Monday       Latte        30.0   2.22    22.20
# 2     Tuesday    Espresso        10.0   5.95    59.50
# 3     Tuesday       Latte        10.0   2.22    22.20
# 4   Wednesday    Espresso        17.5   5.95   208.25
# 5   Wednesday       Latte        25.0   2.22    55.50
# 6    Thursday    Espresso        27.5   5.95   238.00
# 7    Thursday       Latte        30.0   2.22    66.60
# 8      Friday    Espresso        45.0   5.95   267.75
# 9      Friday       Latte        35.0   2.22    77.70
# 10   Saturday    Espresso        45.0   5.95   267.75
# 11   Saturday       Latte        35.0   2.22    77.70
# 12     Sunday    Espresso        45.0   5.95   267.75
# 13     Sunday       Latte        35.0   2.22    77.70

# %%
coffee[coffee["Units Sold"].notna()]

# %% [markdown]
# Aggregating
